# %%
import pandas as pd

# Cargar el archivo Excel que está en el notebook
file_path_excel = 'Conjunto_de_datos.xlsx'  
df_excel = pd.read_excel(file_path_excel)

# Crear un nuevo DataFrame con las columnas seleccionadas
df_csv = pd.DataFrame()

# Añadir las columnas con los prefijos NS_
df_csv['NS_AS1_avg'] = df_excel.iloc[:, 2]  # Columna C
df_csv['NS_AS1_max'] = df_excel.iloc[:, 3]  # Columna D
df_csv['NS_AS1_min'] = df_excel.iloc[:, 5]  # Columna F
df_csv['NS_AS2_avg'] = df_excel.iloc[:, 9]  # Columna J
df_csv['NS_AS2_max'] = df_excel.iloc[:, 10]  # Columna K
df_csv['NS_AS2_min'] = df_excel.iloc[:, 12]  # Columna M
df_csv['NS_AS3_avg'] = df_excel.iloc[:, 16]  # Columna Q
df_csv['NS_AS3_max'] = df_excel.iloc[:, 17]  # Columna R
df_csv['NS_AS3_min'] = df_excel.iloc[:, 19]  # Columna T
df_csv['NS_F1_avg'] = df_excel.iloc[:, 23]  # Columna X
df_csv['NS_F1_max'] = df_excel.iloc[:, 24]  # Columna Y
df_csv['NS_F1_min'] = df_excel.iloc[:, 26]  # Columna AA
df_csv['NS_F2_avg'] = df_excel.iloc[:, 30]  # Columna AE
df_csv['NS_F2_max'] = df_excel.iloc[:, 31]  # Columna AF
df_csv['NS_F2_min'] = df_excel.iloc[:, 33]  # Columna AH
df_csv['NS_F3_avg'] = df_excel.iloc[:, 37]  # Columna AL
df_csv['NS_F3_max'] = df_excel.iloc[:, 38]  # Columna AM
df_csv['NS_F3_min'] = df_excel.iloc[:, 40]  # Columna AO
df_csv['NS_E_avg'] = df_excel.iloc[:, 44]  # Columna AS
df_csv['NS_E_max'] = df_excel.iloc[:, 45]  # Columna AT
df_csv['NS_E_min'] = df_excel.iloc[:, 47]  # Columna AV

# Añadir las columnas con los prefijos EW_
df_csv['EW_AS1_avg'] = df_excel.iloc[:, 51]  # Columna AZ
df_csv['EW_AS1_max'] = df_excel.iloc[:, 52]  # Columna BA
df_csv['EW_AS1_min'] = df_excel.iloc[:, 54]  # Columna BC
df_csv['EW_AS2_avg'] = df_excel.iloc[:, 58]  # Columna BG
df_csv['EW_AS2_max'] = df_excel.iloc[:, 59]  # Columna BH
df_csv['EW_AS2_min'] = df_excel.iloc[:, 61]  # Columna BJ
df_csv['EW_AS3_avg'] = df_excel.iloc[:, 65]  # Columna BN
df_csv['EW_AS3_max'] = df_excel.iloc[:, 66]  # Columna BO
df_csv['EW_AS3_min'] = df_excel.iloc[:, 68]  # Columna BQ
df_csv['EW_F1_avg'] = df_excel.iloc[:, 72]  # Columna BU
df_csv['EW_F1_max'] = df_excel.iloc[:, 73]  # Columna BV
df_csv['EW_F1_min'] = df_excel.iloc[:, 75]  # Columna BX
df_csv['EW_F2_avg'] = df_excel.iloc[:, 79]  # Columna CB
df_csv['EW_F2_max'] = df_excel.iloc[:, 80]  # Columna CC
df_csv['EW_F2_min'] = df_excel.iloc[:, 82]  # Columna CE
df_csv['EW_F3_avg'] = df_excel.iloc[:, 86]  # Columna CI
df_csv['EW_F3_max'] = df_excel.iloc[:, 87]  # Columna CJ
df_csv['EW_F3_min'] = df_excel.iloc[:, 89]  # Columna CL
df_csv['EW_E_avg'] = df_excel.iloc[:, 93]  # Columna CP
df_csv['EW_E_max'] = df_excel.iloc[:, 94]  # Columna CQ
df_csv['EW_E_min'] = df_excel.iloc[:, 96]  # Columna CS

# Añadir la columna de la etiqueta K_avg
df_csv['K_avg'] = df_excel.iloc[:, 111]  # Columna CZ

# Guardar el archivo como CSV en la misma carpeta que el notebook
output_csv_file = 'RS_13_15_final_dataset_UK.csv'  
df_csv.to_csv(output_csv_file, index=False, header=True)

print(f"Archivo guardado correctamente como '{output_csv_file}'")
# Out:
# Archivo guardado correctamente como 'RS_13_15_final_dataset_UK.csv'

# %%
import pandas as pd

# Cargar el archivo Excel que está en el notebook
file_path_excel = 'Conjunto_de_datos.xlsx'  
df_excel = pd.read_excel(file_path_excel)

# Crear un nuevo DataFrame con las columnas seleccionadas
df_csv = pd.DataFrame()

# Añadir las columnas con los prefijos NS_
df_csv['NS_AS1_avg'] = df_excel.iloc[:, 2]  # Columna C
df_csv['NS_AS1_max'] = df_excel.iloc[:, 3]  # Columna D
df_csv['NS_AS1_min'] = df_excel.iloc[:, 5]  # Columna F
df_csv['NS_AS2_avg'] = df_excel.iloc[:, 9]  # Columna J
df_csv['NS_AS2_max'] = df_excel.iloc[:, 10]  # Columna K
df_csv['NS_AS2_min'] = df_excel.iloc[:, 12]  # Columna M
df_csv['NS_AS3_avg'] = df_excel.iloc[:, 16]  # Columna Q
df_csv['NS_AS3_max'] = df_excel.iloc[:, 17]  # Columna R
df_csv['NS_AS3_min'] = df_excel.iloc[:, 19]  # Columna T
df_csv['NS_F1_avg'] = df_excel.iloc[:, 23]  # Columna X
df_csv['NS_F1_max'] = df_excel.iloc[:, 24]  # Columna Y
df_csv['NS_F1_min'] = df_excel.iloc[:, 26]  # Columna AA
df_csv['NS_F2_avg'] = df_excel.iloc[:, 30]  # Columna AE
df_csv['NS_F2_max'] = df_excel.iloc[:, 31]  # Columna AF
df_csv['NS_F2_min'] = df_excel.iloc[:, 33]  # Columna AH
df_csv['NS_F3_avg'] = df_excel.iloc[:, 37]  # Columna AL
df_csv['NS_F3_max'] = df_excel.iloc[:, 38]  # Columna AM
df_csv['NS_F3_min'] = df_excel.iloc[:, 40]  # Columna AO
df_csv['NS_E_avg'] = df_excel.iloc[:, 44]  # Columna AS
df_csv['NS_E_max'] = df_excel.iloc[:, 45]  # Columna AT
df_csv['NS_E_min'] = df_excel.iloc[:, 47]  # Columna AV

# Añadir las columnas con los prefijos EW_
df_csv['EW_AS1_avg'] = df_excel.iloc[:, 51]  # Columna AZ
df_csv['EW_AS1_max'] = df_excel.iloc[:, 52]  # Columna BA
df_csv['EW_AS1_min'] = df_excel.iloc[:, 54]  # Columna BC
df_csv['EW_AS2_avg'] = df_excel.iloc[:, 58]  # Columna BG
df_csv['EW_AS2_max'] = df_excel.iloc[:, 59]  # Columna BH
df_csv['EW_AS2_min'] = df_excel.iloc[:, 61]  # Columna BJ
df_csv['EW_AS3_avg'] = df_excel.iloc[:, 65]  # Columna BN
df_csv['EW_AS3_max'] = df_excel.iloc[:, 66]  # Columna BO
df_csv['EW_AS3_min'] = df_excel.iloc[:, 68]  # Columna BQ
df_csv['EW_F1_avg'] = df_excel.iloc[:, 72]  # Columna BU
df_csv['EW_F1_max'] = df_excel.iloc[:, 73]  # Columna BV
df_csv['EW_F1_min'] = df_excel.iloc[:, 75]  # Columna BX
df_csv['EW_F2_avg'] = df_excel.iloc[:, 79]  # Columna CB
df_csv['EW_F2_max'] = df_excel.iloc[:, 80]  # Columna CC
df_csv['EW_F2_min'] = df_excel.iloc[:, 82]  # Columna CE
df_csv['EW_F3_avg'] = df_excel.iloc[:, 86]  # Columna CI
df_csv['EW_F3_max'] = df_excel.iloc[:, 87]  # Columna CJ
df_csv['EW_F3_min'] = df_excel.iloc[:, 89]  # Columna CL
df_csv['EW_E_avg'] = df_excel.iloc[:, 93]  # Columna CP
df_csv['EW_E_max'] = df_excel.iloc[:, 94]  # Columna CQ
df_csv['EW_E_min'] = df_excel.iloc[:, 96]  # Columna CS

# Añadir la columna de la etiqueta K_avg
df_csv['K_avg'] = df_excel.iloc[:, 100]  # Columna CW

# Guardar el archivo como CSV en la misma carpeta que el notebook
output_csv_file = 'RS_13_15_final_dataset_ALEMANIA.csv'  
df_csv.to_csv(output_csv_file, index=False, header=True)

print(f"Archivo guardado correctamente como '{output_csv_file}'")
# Out:
# Archivo guardado correctamente como 'RS_13_15_final_dataset_ALEMANIA.csv'

# %%
import pandas as pd

# Cargar el archivo Excel que está en el notebook
file_path_excel = 'Conjunto_de_datos.xlsx'  
df_excel = pd.read_excel(file_path_excel)


# Crear un nuevo DataFrame con las columnas seleccionadas
df_csv = pd.DataFrame()

# Añadir las columnas seleccionadas de frecuencia
df_csv['NS_F1_avg'] = df_excel.iloc[:, 23]  # Columna X
df_csv['NS_F1_max'] = df_excel.iloc[:, 24]  # Columna Y
df_csv['NS_F1_min'] = df_excel.iloc[:, 26]  # Columna AA
df_csv['NS_F2_avg'] = df_excel.iloc[:, 30]  # Columna AE
df_csv['NS_F2_max'] = df_excel.iloc[:, 31]  # Columna AF
df_csv['NS_F2_min'] = df_excel.iloc[:, 33]  # Columna AH
df_csv['NS_F3_avg'] = df_excel.iloc[:, 37]  # Columna AL
df_csv['NS_F3_max'] = df_excel.iloc[:, 38]  # Columna AM
df_csv['NS_F3_min'] = df_excel.iloc[:, 40]  # Columna AO
df_csv['EW_F1_avg'] = df_excel.iloc[:, 72]  # Columna BU
df_csv['EW_F1_max'] = df_excel.iloc[:, 73]  # Columna BV
df_csv['EW_F1_min'] = df_excel.iloc[:, 75]  # Columna BX
df_csv['EW_F2_avg'] = df_excel.iloc[:, 79]  # Columna CB
df_csv['EW_F2_max'] = df_excel.iloc[:, 80]  # Columna CC
df_csv['EW_F2_min'] = df_excel.iloc[:, 82]  # Columna CE
df_csv['EW_F3_avg'] = df_excel.iloc[:, 86]  # Columna CI
df_csv['EW_F3_max'] = df_excel.iloc[:, 87]  # Columna CJ
df_csv['EW_F3_min'] = df_excel.iloc[:, 89]  # Columna CL
df_csv['K_avg'] = df_excel.iloc[:, 111]  # Columna UK

# Guardar el archivo como CSV
output_csv_file = 'RS_13_15_final_dataset_FRECUENCIA.csv'
df_csv.to_csv(output_csv_file, index=False)

print(f"Conjunto de datos guardado en {output_csv_file}")
# Out:
# Conjunto de datos guardado en RS_13_15_final_dataset_FRECUENCIA.csv

# %%
# Cargar el archivo Excel que está en el notebook avg
file_path_excel = 'Conjunto_de_datos.xlsx'  
df_excel = pd.read_excel(file_path_excel)

# Crear un nuevo DataFrame con las columnas seleccionadas
df_csv = pd.DataFrame()

# Añadir las columnas con los prefijos NS_
df_csv['NS_AS1_avg'] = df_excel.iloc[:, 2]  # Columna C

df_csv['NS_AS2_avg'] = df_excel.iloc[:, 9]  # Columna J

df_csv['NS_AS3_avg'] = df_excel.iloc[:, 16]  # Columna Q

df_csv['NS_F1_avg'] = df_excel.iloc[:, 23]  # Columna X

df_csv['NS_F2_avg'] = df_excel.iloc[:, 30]  # Columna AE

df_csv['NS_F3_avg'] = df_excel.iloc[:, 37]  # Columna AL

df_csv['NS_E_avg'] = df_excel.iloc[:, 44]  # Columna AS


# Añadir las columnas con los prefijos EW_
df_csv['EW_AS1_avg'] = df_excel.iloc[:, 51]  # Columna AZ

df_csv['EW_AS2_avg'] = df_excel.iloc[:, 58]  # Columna BG

df_csv['EW_AS3_avg'] = df_excel.iloc[:, 65]  # Columna BN

df_csv['EW_F1_avg'] = df_excel.iloc[:, 72]  # Columna BU

df_csv['EW_F2_avg'] = df_excel.iloc[:, 79]  # Columna CB

df_csv['EW_F3_avg'] = df_excel.iloc[:, 86]  # Columna CI


df_csv['EW_E_avg'] = df_excel.iloc[:, 93]  # Columna CP


# Añadir la columna de la etiqueta K_avg
df_csv['K_avg'] = df_excel.iloc[:, 111]  # Columna CW

# Guardar el archivo como CSV en la misma carpeta que el notebook
output_csv_file = 'RS_13_15_final_dataset_AVG.csv'  
df_csv.to_csv(output_csv_file, index=False, header=True)

print(f"Archivo guardado correctamente como '{output_csv_file}'")
# Out:
# Archivo guardado correctamente como 'RS_13_15_final_dataset_AVG.csv'
